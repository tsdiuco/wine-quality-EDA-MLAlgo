# %% [markdown]
# # Exploratory Data Analysis

# %%
import importlib
import os

import mysklearn.myutils as myutils
import mysklearn.utils as utils
import mysklearn.plot_utils as plot_utils
import mysklearn.mypytable as mypytable

input_file = os.path.join("data", "WineQT.csv")
data_table = mypytable.MyPyTable()
data_table.load_from_file(input_file)

# %% [markdown]
# ## Equal Bin Width Frequency Diagram

# %%
importlib.reload(importlib)
importlib.reload(os)
importlib.reload(myutils)
importlib.reload(plot_utils)
importlib.reload(mypytable)

acid_column = utils.get_column(data_table.data, data_table.column_names, "fixed acidity")

cutoffs = utils.compute_equal_width_cutoffs(acid_column, 5)
freqs = utils.compute_bin_frequencies(acid_column, cutoffs)

plot_utils.discretization_bar_chart(freqs, cutoffs, "Equal Width Chart", "Fixed Acidity", "Total")

# %% [markdown]
# ## Histogram

# %% [markdown]
# ### Calssification - Quality

# %%
importlib.reload(importlib)
importlib.reload(os)
importlib.reload(myutils)
importlib.reload(plot_utils)
importlib.reload(mypytable)

quality_column = utils.get_column(data_table.data, data_table.column_names, "quality")
plot_utils.create_histogram("Quality Histogram", "Quality", "Count", quality_column)

# %% [markdown]
# ### pH

# %%
importlib.reload(importlib)
importlib.reload(os)
importlib.reload(myutils)
importlib.reload(plot_utils)
importlib.reload(mypytable)

ph_column = utils.get_column(data_table.data, data_table.column_names, "pH")
plot_utils.create_histogram("PH Histogram", "pH", "Count", ph_column)

# %% [markdown]
# ### Alcohol Content

# %%
importlib.reload(importlib)
importlib.reload(os)
importlib.reload(myutils)
importlib.reload(plot_utils)
importlib.reload(mypytable)

alc_column = utils.get_column(data_table.data, data_table.column_names, "alcohol")
plot_utils.create_histogram("Alcohol Histogram", "Alcohol", "Count", alc_column)

# %% [markdown]
# ## Continuous/Continuous Relationships

# %% [markdown]
# ### Alcohol and Quality

# %%
importlib.reload(importlib)
importlib.reload(os)
importlib.reload(myutils)
importlib.reload(plot_utils)
importlib.reload(mypytable)

alc_column = utils.get_column(data_table.data, data_table.column_names, "alcohol")
quality_column = utils.get_column(data_table.data, data_table.column_names, "quality")

plot_utils.create_scatter_plot("Alcohol and Quality", "Alcohol", "Quality", alc_column, quality_column)

# %% [markdown]
# ### pH and Quality

# %%
importlib.reload(importlib)
importlib.reload(os)
importlib.reload(myutils)
importlib.reload(plot_utils)
importlib.reload(mypytable)

ph_column = utils.get_column(data_table.data, data_table.column_names, "pH")
quality_column = utils.get_column(data_table.data, data_table.column_names, "quality")

plot_utils.create_scatter_plot("pH and Quality", "pH", "Quality", ph_column, quality_column)

# %% [markdown]
# ### pH and Fixed Acidity

# %%
importlib.reload(importlib)
importlib.reload(os)
importlib.reload(myutils)
importlib.reload(plot_utils)
importlib.reload(mypytable)

ph_column = utils.get_column(data_table.data, data_table.column_names, "pH")
acid_column = utils.get_column(data_table.data, data_table.column_names, "fixed acidity")

plot_utils.create_scatter_plot("pH and Fixed Acidity", "pH", "Fixed Acidity", ph_column, acid_column)

# %% [markdown]
# ### Fixed Acidity and Quality

# %%
importlib.reload(importlib)
importlib.reload(os)
importlib.reload(myutils)
importlib.reload(plot_utils)
importlib.reload(mypytable)

acid_column = utils.get_column(data_table.data, data_table.column_names, "fixed acidity")
quality_column = utils.get_column(data_table.data, data_table.column_names, "quality")

plot_utils.create_scatter_plot("Fixed Acidity and Quality", "Fixed Acidity", "Quality", acid_column, quality_column)

# %% [markdown]
# ### Residual Sugar and Quality

# %%
importlib.reload(importlib)
importlib.reload(os)
importlib.reload(myutils)
importlib.reload(plot_utils)
importlib.reload(mypytable)

sugar_column = utils.get_column(data_table.data, data_table.column_names, "residual sugar")
quality_column = utils.get_column(data_table.data, data_table.column_names, "quality")

plot_utils.create_scatter_plot("Residual Sugar and Quality", "Residual Sugar", "Quality", sugar_column, quality_column)
